# %% [markdown]
# # Data Preparation

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
import pickle

import numpy as np

import os

# %%
df = pd.read_csv('../csv/starting.csv')
df
# Out:
#                                                   paths       patient_id  \
# 0     /project/GutIntelligenceLab/ss4yd/gtex_data/ac...  GTEX-14DAR-0426
# 1     /project/GutIntelligenceLab/ss4yd/gtex_data/ac...  GTEX-13QBU-0926
# 2     /project/GutIntelligenceLab/ss4yd/gtex_data/ac...  GTEX-18QFQ-0326
# 3     /project/GutIntelligenceLab/ss4yd/gtex_data/ac...  GTEX-139YR-1526
# 4     /project/GutIntelligenceLab/ss4yd/gtex_data/ac...   GTEX-R55C-0526
# ...                                                 ...              ...
# 7723  /project/GutIntelligenceLab/ss4yd/gtex_data/ac...  GTEX-1GTWX-0626
# 7724  /project/GutIntelligenceLab/ss4yd/gtex_data/ac...  GTEX-1AX8Z-2226
# 7725  /project/GutIntelligenceLab/ss4yd/gtex_data/ac...  GTEX-1J8Q3-1526
# 7726  /project/GutIntelligenceLab/ss4yd/gtex_data/ac...   GTEX-UJHI-0126
# 7727  /project/GutIntelligenceLab/ss4yd/gtex_data/ac...  GTEX-1477Z-0626
#
#                             tissue                cat  \
# 0     Adipose - Visceral (Omentum)        hyperplasia
# 1           Esophagus - Muscularis    clean_specimens
# 2                Muscle - Skeletal            atrophy
# 3                         Pancreas           fibrosis
# 4                             Lung          emphysema
# ...                            ...                ...
# 7723                          Lung         congestion
# 7724                       Stomach          gastritis
# 7725        Adipose - Subcutaneous           fibrosis
# 7726                        Spleen         congestion
# 7727                          Lung  congestion, edema
#
#                                                   notes  maj_tissue  \
# 0     2 pieces, ~5% fasca, delineated. Minute focus ...    Adipose
# 1              6 pieces, all muscularis, good specimens  Esophagus
# 2     2 pieces; skeletal muscle with scant internal ...     Muscle
# 3     2 pieces; islets well visualized, focal PanIN-...    Pancreas
# 4            2 pieces, 10x7 & 8x5 mm; patchy  emphysema        Lung
# ...                                                 ...         ...
# 7723                      2 pieces, moderate congestion        Lung
# 7724  6 pieces: 2 without muscularis; chronic gastritis     Stomach
# 7725                     2 pieces; <10% fibrous content    Adipose
# 7726  2 pieces, 8x7 & 8x7mm; moderate congestion; di...      Spleen
# 7727  2 pieces, moderate-marked congestion/edema, br...        Lung
#
#                 size
# 0     (55775, 37700)
# 1     (71711, 40331)
# 2     (49799, 24496)
# 3     (63743, 37311)
# 4     (39839, 32246)
# ...              ...
# 7723  (41831, 26034)
# 7724  (51791, 35651)
# 7725  (53783, 38942)
# 7726  (45815, 32790)
# 7727  (45815, 33036)
#
# [7728 rows x 7 columns]

# %%
vectorizer = CountVectorizer()

vectorizer.fit(df.notes)

vocab = vectorizer.vocabulary_

processor = vectorizer.build_preprocessor()
tokenizer = vectorizer.build_tokenizer()

df['tokens'] = df.notes.apply(processor)
df['tokens'] = df.tokens.apply(tokenizer)

# https://datagy.io/python-remove-punctuation-from-string/#:~:text=One%20of%20the%20easiest%20ways,maketrans()%20method.
import string
df['strp_punc'] = df['notes'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))

df['1stword'] = df['strp_punc'].apply(lambda x: x.split(' ')[0].lower())

df['1stword'] = df['1stword'].apply(lambda x: x if x not in vocab.keys() else None)
df['1stword'] = df['1stword'].apply(lambda x: [x])

df['complete_tokens'] = df['1stword'] + df['tokens']

df.to_pickle('../csv/tokenized_data.pkl')
df
# Out:
#                                                   paths       patient_id  \
# 0     /project/GutIntelligenceLab/ss4yd/gtex_data/ac...  GTEX-14DAR-0426
# 1     /project/GutIntelligenceLab/ss4yd/gtex_data/ac...  GTEX-13QBU-0926
# 2     /project/GutIntelligenceLab/ss4yd/gtex_data/ac...  GTEX-18QFQ-0326
# 3     /project/GutIntelligenceLab/ss4yd/gtex_data/ac...  GTEX-139YR-1526
# 4     /project/GutIntelligenceLab/ss4yd/gtex_data/ac...   GTEX-R55C-0526
# ...                                                 ...              ...
# 7723  /project/GutIntelligenceLab/ss4yd/gtex_data/ac...  GTEX-1GTWX-0626
# 7724  /project/GutIntelligenceLab/ss4yd/gtex_data/ac...  GTEX-1AX8Z-2226
# 7725  /project/GutIntelligenceLab/ss4yd/gtex_data/ac...  GTEX-1J8Q3-1526
# 7726  /project/GutIntelligenceLab/ss4yd/gtex_data/ac...   GTEX-UJHI-0126
# 7727  /project/GutIntelligenceLab/ss4yd/gtex_data/ac...  GTEX-1477Z-0626
#
#                             tissue                cat  \
# 0     Adipose - Visceral (Omentum)        hyperplasia
# 1           Esophagus - Muscularis    clean_specimens
# 2                Muscle - Skeletal            atrophy
# 3                         Pancreas           fibrosis
# 4                             Lung          emphysema
# ...                            ...                ...
# 7723                          Lung         congestion
# 7724                       Stomach          gastritis
# 7725        Adipose - Subcutaneous           fibrosis
# 7726                        Spleen         congestion
# 7727                          Lung  congestion, edema
#
#                                                   notes  maj_tissue  \
# 0     2 pieces, ~5% fasca, delineated. Minute focus ...    Adipose
# 1              6 pieces, all muscularis, good specimens  Esophagus
# 2     2 pieces; skeletal muscle with scant internal ...     Muscle
# 3     2 pieces; islets well visualized, focal PanIN-...    Pancreas
# 4            2 pieces, 10x7 & 8x5 mm; patchy  emphysema        Lung
# ...                                                 ...         ...
# 7723                      2 pieces, moderate congestion        Lung
# 7724  6 pieces: 2 without muscularis; chronic gastritis     Stomach
# 7725                     2 pieces; <10% fibrous content    Adipose
# 7726  2 pieces, 8x7 & 8x7mm; moderate congestion; di...      Spleen
# 7727  2 pieces, moderate-marked congestion/edema, br...        Lung
#
#                 size                                             tokens  \
# 0     (55775, 37700)  [pieces, fasca, delineated, minute, focus, of,...
# 1     (71711, 40331)         [pieces, all, muscularis, good, specimens]
# 2     (49799, 24496)  [pieces, skeletal, muscle, with, scant, intern...
# 3     (63743, 37311)  [pieces, islets, well, visualized, focal, pani...
# 4     (39839, 32246)         [pieces, 10x7, 8x5, mm, patchy, emphysema]
# ...              ...                                                ...
# 7723  (41831, 26034)                     [pieces, moderate, congestion]
# 7724  (51791, 35651)  [pieces, without, muscularis, chronic, gastritis]
# 7725  (53783, 38942)                     [pieces, 10, fibrous, content]
# 7726  (45815, 32790)  [pieces, 8x7, 8x7mm, moderate, congestion, dis...
# 7727  (45815, 33036)  [pieces, moderate, marked, congestion, edema, ...
#
#                                               strp_punc 1stword  \
# 0     2 pieces 5 fasca delineated Minute focus of me...     [2]
# 1                6 pieces all muscularis good specimens     [6]
# 2     2 pieces skeletal muscle with scant internal f...     [2]
# 3     2 pieces islets well visualized focal PanIN1 s...     [2]
# 4               2 pieces 10x7  8x5 mm patchy  emphysema     [2]
# ...                                                 ...     ...
# 7723                       2 pieces moderate congestion     [2]
# 7724    6 pieces 2 without muscularis chronic gastritis     [6]
# 7725                        2 pieces 10 fibrous content     [2]
# 7726  2 pieces 8x7  8x7mm moderate congestion discre...     [2]
# 7727  2 pieces moderatemarked congestionedema bronch...     [2]
#
#                                         complete_tokens
# 0     [2, pieces, fasca, delineated, minute, focus, ...
# 1         [6, pieces, all, muscularis, good, specimens]
# 2     [2, pieces, skeletal, muscle, with, scant, int...
# 3     [2, pieces, islets, well, visualized, focal, p...
# 4         [2, pieces, 10x7, 8x5, mm, patchy, emphysema]
# ...                                                 ...
# 7723                  [2, pieces, moderate, congestion]
# 7724  [6, pieces, without, muscularis, chronic, gast...
# 7725                  [2, pieces, 10, fibrous, content]
# 7726  [2, pieces, 8x7, 8x7mm, moderate, congestion, ...
# 7727  [2, pieces, moderate, marked, congestion, edem...
#
# [7728 rows x 11 columns]

# %%
for word in pd.unique(df['1stword'].apply(lambda x: x[0])):
    vocab[word]=len(vocab)

with open('../csv/word2idx.pickle','wb') as file:
    pickle.dump(vocab, file)

# %%
patch_path = '/project/GutIntelligenceLab/ss4yd/gtex_data/process_path_level1/'
dirs = os.listdir(patch_path)
dir_patch_dict = {}
for pid in dirs:
    patches = [os.path.join(patch_path, pid, x) for x in os.listdir(os.path.join(patch_path, pid))]
    dir_patch_dict[pid] = patches
    
patch_paths = [x for xs in dir_patch_dict.values() for x in xs]

# %%
pdf = pd.DataFrame(patch_paths, columns=['patch_paths'])

pdf['pid'] = pdf['patch_paths'].apply(lambda x: x.split('/')[-2])

split = pd.read_csv('../csv/train_test_val_split.csv')

train = split[split['dtype']=='train'].sample(frac=0.1, random_state=1)
val = split[split['dtype']=='val'].sample(frac=0.1, random_state=1)
test = split[split['dtype']=='test'].sample(frac=0.1, random_state=1)

split_small = pd.concat([train, val, test])
print("length smaller split:{}".format(len(split_small)))

pdf = pdf.merge(split_small, on='pid')
print("Number of patches: {}".format(len(pdf)))
# Out:
# length smaller split:773
# Number of patches: 69757

# %%
pdf.to_csv('../csv/working_df.csv', index=False)

# %%
final_df = pdf.merge(df, left_on='pid', right_on='patient_id')

# %%
final_df=final_df.drop(columns=['patient_id', 'paths'])
final_df.to_pickle('../csv/final_starting_df.csv')

# %% [markdown]
# # Get representations

# %%
import pandas as pd
import numpy as np
import os
from PIL import Image

import torch
import torch.nn as nn
from torchvision.io import read_image, ImageReadMode
from torchvision.transforms import ToTensor
import torchvision.transforms as transforms
import torchvision.models as models
import torchvision

from torch.utils.data import Dataset, DataLoader

from tqdm.notebook import trange, tqdm

# %%
class GetRepsDataset(Dataset):
    
    def __init__(self, df, dtype, transform=None):
        self.df = df
        self.dtype = dtype
        self.transform = transform
        self.typ_df = df[df['dtype']==dtype]
        
    def __len__(self):
        return len(self.typ_df)
    
    def __getitem__(self, idx):
        img_path = self.typ_df.patch_paths.iloc[idx]
        
        image = read_image(img_path, mode=ImageReadMode.RGB)
        
        if self.transform:
            image = self.transform(image)
        return image, img_path

# %%
normalize = transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))

transform=transforms.Compose([
    transforms.Resize([224,224]),
    transforms.ConvertImageDtype(torch.float),
    normalize,
        ])

train_dataset = GetRepsDataset(final_df, 'train', transform)
train_loader = torch.utils.data.DataLoader(train_dataset,batch_size=64, shuffle=True, num_workers=1, pin_memory=True)

train_loader.dataset.__getitem__(1)
# Out:
# (tensor([[[ 1.9235,  1.4098,  0.9646,  ..., -0.1143,  0.3481,  0.8447],
#           [ 1.1700,  1.0673,  0.2111,  ..., -0.6452,  0.2111,  1.2728],
#           [ 0.7762,  0.7591,  0.1083,  ..., -0.4739, -0.2342,  0.6734],
#           ...,
#           [ 1.2214,  1.3413,  0.6049,  ...,  0.5193,  0.5364,  0.6392],
#           [ 1.5639,  1.6153,  0.5022,  ...,  0.1254,  0.3309,  0.1426],
#           [ 1.6838,  1.5125,  0.8104,  ...,  0.2624,  0.6049, -0.0801]],
#
#          [[ 1.3957,  0.1527, -0.6702,  ..., -1.4755, -1.3529, -0.8978],
#           [-0.5126, -0.9503, -1.2129,  ..., -1.5105, -1.3004, -0.7052],
#           [-1.1429, -1.1604, -1.4055,  ..., -1.5280, -1.3880, -1.0028],
#           ...,
#           [-0.2675, -0.3901, -0.8102,  ..., -1.1954, -1.2654, -1.1078],
#           [-0.3025,  0.0301, -0.8978,  ..., -1.3354, -1.2654, -1.4580],
#           [-0.2325, -0.0574, -0.8627,  ..., -1.2479, -1.1429, -1.4230]],
#
#          [[ 1.5768,  0.7402,  0.1128,  ..., -0.6541, -0.5495,  0.0256],
#           [ 0.3219, -0.0267, -0.5147,  ..., -0.5844, -0.3578,  0.2173],
#           [-0.3404, -0.3753, -0.6715,  ..., -0.6193, -0.6018, -0.1312],
#           ...,
#           [ 0.6182,  0.6705,  0.1651,  ..., -0.3055, -0.2707, -0.2881],
#           [ 0.5311,  0.8448, -0.0092,  ..., -0.2881, -0.4275, -0.6193],
#           [ 0.6182,  1.0017,  0.1999,  ..., -0.2184, -0.3927, -0.4624]]]),
#  '/project/GutIntelligenceLab/ss4yd/gtex_data/process_path_level1/GTEX-R55E-1726/tile_182_level1_18509-10316-19533-11340.png')

# %%
class Resnet18backbone(nn.Module):
    def __init__(self):
        super(Resnet18backbone, self).__init__()
        
        self.resnet_head = nn.Sequential(*list(models.resnet18(pretrained=True).children())[:-1])
        
    def forward(self, x):
        out = self.resnet_head(x)
        return out

# %%
# test
model = Resnet18backbone()

normalize = transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
batch_size = 64

transform=transforms.Compose([
    transforms.Resize([224,224]),
    transforms.ConvertImageDtype(torch.float),
    normalize,
        ])

df = pd.read_csv('../csv/working_df.csv')

train_dataset = GetRepsDataset(df, 'train', transform)
train_loader = torch.utils.data.DataLoader(train_dataset,batch_size=64, shuffle=False, num_workers=1, pin_memory=True)

model(train_loader.dataset.__getitem__(1)[0].unsqueeze(0)).shape
# Out:
# torch.Size([1, 512, 1, 1])

# %%
def check_cuda():
    if torch.cuda.is_available():       
        device = torch.device("cuda")
        print(f'There are {torch.cuda.device_count()} GPU(s) available.')
        print('Device name:', torch.cuda.get_device_name(0))
        return device
    else:
        print('No GPU available, using the CPU instead.')
        device = torch.device("cpu")
        return device
    
device=check_cuda()
# Out:
# No GPU available, using the CPU instead.

# %%
model = model.to(device)

rep_list = []
path_list = []
model.eval()
for img, path in tqdm(train_loader):
    
    img = img.to(device)    
    
    in_batch_size = img.shape[0]
    
    reps = model(img)
    rep_list.append(reps.detach().detach().cpu().numpy().reshape(in_batch_size, -1))
    path_list += path
    
rep_array = np.concatenate(rep_list, axis=0)
repsdf = pd.DataFrame(rep_array)
repsdf['patch_paths']=path_list

repsdf.to_csv('../csv/working_train_reps.csv', index=False)
# Out:
#   0%|          | 0/802 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_182257/644093757.py in <module>
#      10     in_batch_size = img.shape[0]
#      11
# ---> 12     reps = model(img)
#      13     rep_list.append(reps.detach().detach().cpu().numpy().reshape(in_batch_size, -1))
#      14     path_list += path
#
# /usr/local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /tmp/ipykernel_182257/3903999329.py in forward(self, x)
#       6
#       7     def forward(self, x):
# ----> 8         out = self.resnet_head(x)
#       9         return out
#
# /usr/local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# /usr/local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# /usr/local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/site-packages/torchvision/models/resnet.py in forward(self, x)
#      68         identity = x
#      69
# ---> 70         out = self.conv1(x)
#      71         out = self.bn1(out)
#      72         out = self.relu(out)
#
# /usr/local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     444
#     445     def forward(self, input: Tensor) -> Tensor:
# --> 446         return self._conv_forward(input, self.weight, self.bias)
#     447
#     448 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.8/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     440                             weight, bias, self.stride,
#     441                             _pair(0), self.dilation, self.groups)
# --> 442         return F.conv2d(input, weight, bias, self.stride,
#     443                         self.padding, self.dilation, self.groups)
#     444
#
# KeyboardInterrupt:

# %%
valid_dataset = GetRepsDataset(df, 'val', transform)
valid_loader = torch.utils.data.DataLoader(valid_dataset,batch_size=64, shuffle=False, num_workers=1, pin_memory=True)

model = model.to(device)

rep_list = []
path_list = []
model.eval()
for img, path in tqdm(valid_loader):
    
    img = img.to(device)    
    
    in_batch_size = img.shape[0]
    
    reps = model(img)
    rep_list.append(reps.detach().detach().cpu().numpy().reshape(in_batch_size, -1))
    path_list += path
    
rep_array = np.concatenate(rep_list, axis=0)
valrepsdf = pd.DataFrame(rep_array)
valrepsdf['patch_paths']=path_list

valrepsdf.to_csv('../csv/working_valid_reps.csv', index=False)

# %% [markdown]
# # Cluster using faiss

# %%
import faiss

# %%
repsdf = pd.read_csv('../csv/working_train_reps.csv')
final_df = pd.read_pickle('../csv/final_starting_df.csv')

# %%
repsdf

# %%
X = repsdf[[str(x) for x in list(range(512))]]
X = np.ascontiguousarray(X)
X = X.astype('float32')

# %%
ncentroids = 8
niter = 300
verbose = False
d = X.shape[1]
kmeans = faiss.Kmeans(d, ncentroids, niter=niter, verbose=verbose, nredo=20)
kmeans.train(X)
# Out:
# 255477.296875

# %%
D, I = kmeans.index.search(X, 1)

repsdf['cluster_assignment']=I

repsdf['reps']=repsdf[[str(x) for x in range(512)]].values.tolist()
repsdf=repsdf.drop(columns=[str(x) for x in range(512)])

repsdf['pid'] = repsdf['patch_paths'].apply(lambda x: x.split('/')[-2])
repsdf

# %%
valreps = pd.read_csv('../csv/working_valid_reps.csv')
X_val = valreps[[str(x) for x in list(range(512))]]
X_val = np.ascontiguousarray(X_val)
X_val = X_val.astype('float32')

D, I = kmeans.index.search(X_val, 1)

valreps['cluster_assignment']=I

valreps['reps']=valreps[[str(x) for x in range(512)]].values.tolist()
valreps=valreps.drop(columns=[str(x) for x in range(512)])

valreps['pid'] = valreps['patch_paths'].apply(lambda x: x.split('/')[-2])
valreps

# %%
repsdf = pd.concat([repsdf, valreps])

# %%
final_df['pid']

# %%
generatingdf=repsdf.drop(columns=['reps']).merge(final_df.drop_duplicates('pid'),on='pid')

generatingdf=generatingdf.drop(columns=['patch_paths_y','tokens','1stword'])

generatingdf

# %%
generatingdf = generatingdf[['patch_paths_x','pid','cluster_assignment','complete_tokens','dtype','notes']]

generatingdf

# %%
generatingdf.to_pickle('../csv/generating_training_df.pickle')
